# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Reading in datasets for each month for yellow cabs
jan_df = pd.read_csv('./data/2020/yellow_2020-01.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
jan_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 6405003       NaN  2020-01-31 22:51:00   2020-01-31 23:22:00              NaN
# 6405004       NaN  2020-01-31 22:10:00   2020-01-31 23:26:00              NaN
# 6405005       NaN  2020-01-31 22:50:07   2020-01-31 23:17:57              NaN
# 6405006       NaN  2020-01-31 22:25:53   2020-01-31 22:48:32              NaN
# 6405007       NaN  2020-01-31 22:44:00   2020-01-31 23:06:00              NaN
#
# ...

# %%
len(jan_df)
# Out:
# 6405008

# %%
jan_df.isna().sum()
# Out:
# VendorID                 65441
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          65441
# trip_distance                0
# RatecodeID               65441
# store_and_fwd_flag       65441
# PULocationID                 0
# DOLocationID                 0
# payment_type             65441
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# dtype: int64

# %%
taxi_zones = pd.read_csv('./data/taxi_zones.csv')

# %%
taxi_zones
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
taxi_zones.isna().sum()
# Out:
# LocationID      0
# Borough         0
# Zone            1
# service_zone    2
# dtype: int64

# %%
taxi_zones[taxi_zones['Zone'].isna()]
# Out:
#      LocationID  Borough Zone service_zone
# 264         265  Unknown  NaN          NaN

# %%
taxi_zones[taxi_zones['LocationID'] == 238]
# Out:
#      LocationID    Borough                   Zone service_zone
# 237         238  Manhattan  Upper West Side North  Yellow Zone

# %%
yellow_cab_2015_df = pd.read_csv('./data/yellow_tripdata_2015-01.csv')

# %%
yellow_cab_2015_df
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2015-01-15 19:05:39   2015-01-15 19:23:42
# 1                1  2015-01-10 20:33:38   2015-01-10 20:53:28
# 2                1  2015-01-10 20:33:38   2015-01-10 20:43:41
# 3                1  2015-01-10 20:33:39   2015-01-10 20:35:31
# 4                1  2015-01-10 20:33:39   2015-01-10 20:52:58
# ...            ...                  ...                   ...
# 12748981         1  2015-01-10 19:01:44   2015-01-10 19:05:40
# 12748982         1  2015-01-10 19:01:44   2015-01-10 19:07:26
# 12748983         1  2015-01-10 19:01:44   2015-01-10 19:15:01
# 12748984         1  2015-01-10 19:01:44   2015-01-10 19:17:03
# 12748985         1  2015-01-10 19:01:45   2015-01-10 19:07:33
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       1           1.59        -73.993896        40.750111
# ...

# %%
yellow_cab_2015_df.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RateCodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    3
# total_amount             0
# dtype: int64

# %%
yellow_cab_2016_df = pd.read_csv('./data/yellow_tripdata_2016-01.csv')

# %%
yellow_cab_2016_df
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 1                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 2                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 3                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 4                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# ...            ...                  ...                   ...
# 10906853         2  2016-01-31 23:30:32   2016-01-31 23:38:18
# 10906854         1  2016-01-05 00:15:55   2016-01-05 00:16:06
# 10906855         1  2016-01-05 06:12:46   2016-03-19 20:45:50
# 10906856         1  2016-01-05 06:21:44   2016-03-28 12:54:26
# 10906857         1  2016-01-05 06:15:21   2016-01-05 06:15:36
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       2           1.10        -73.990372        40.734695
# ...

# %%
yellow_cab_2017_df = pd.read_csv('./data/yellow_tripdata_2017-01.csv')

# %%
yellow_cab_2017_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2017-01-09 11:13:28   2017-01-09 11:25:45                1
# 1               1  2017-01-09 11:32:27   2017-01-09 11:36:01                1
# 2               1  2017-01-09 11:38:20   2017-01-09 11:42:05                1
# 3               1  2017-01-09 11:52:13   2017-01-09 11:57:36                1
# 4               2  2017-01-01 00:00:00   2017-01-01 00:00:00                1
# ...           ...                  ...                   ...              ...
# 9710119         2  2017-01-31 23:59:58   2017-02-01 00:20:01                1
# 9710120         2  2017-01-31 23:59:58   2017-02-01 00:03:43                1
# 9710121         1  2017-01-31 23:59:59   2017-02-01 00:24:35                2
# 9710122         2  2017-01-31 23:59:59   2017-02-01 00:21:15                1
# 9710123         2  2017-01-31 23:59:59   2017-02-01 00:07:50                3
#
# ...

# %%
### EXTRAS: WAIT BEFORE MVP

# %%
# February
feb_df = pd.read_csv('./data/2020/yellow_2020-02.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
feb_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-02-01 00:17:35   2020-02-01 00:30:32              1.0
# 1             1.0  2020-02-01 00:32:47   2020-02-01 01:05:36              1.0
# 2             1.0  2020-02-01 00:31:44   2020-02-01 00:43:28              1.0
# 3             2.0  2020-02-01 00:07:35   2020-02-01 00:31:39              1.0
# 4             2.0  2020-02-01 00:51:43   2020-02-01 01:01:29              1.0
# ...           ...                  ...                   ...              ...
# 6299349       NaN  2020-02-28 14:28:00   2020-02-28 14:54:00              NaN
# 6299350       NaN  2020-02-28 14:03:00   2020-02-28 14:11:00              NaN
# 6299351       NaN  2020-02-28 14:55:00   2020-02-28 15:02:00              NaN
# 6299352       NaN  2020-02-28 14:29:00   2020-02-28 14:51:00              NaN
# 6299353       NaN  2020-02-28 14:06:00   2020-02-28 14:38:00              NaN
#
# ...

# %%
feb_df.isna().sum()
# Out:
# VendorID                 48834
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          48834
# trip_distance                0
# RatecodeID               48834
# store_and_fwd_flag       48834
# PULocationID                 0
# DOLocationID                 0
# payment_type             48834
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# dtype: int64

# %%
march_df = pd.read_csv('./data/2020/yellow_2020-03.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
march_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-03-01 00:31:13   2020-03-01 01:01:42              1.0
# 1             2.0  2020-03-01 00:08:22   2020-03-01 00:08:49              1.0
# 2             1.0  2020-03-01 00:52:18   2020-03-01 00:59:16              1.0
# 3             2.0  2020-03-01 00:47:53   2020-03-01 00:50:57              2.0
# 4             1.0  2020-03-01 00:43:19   2020-03-01 00:58:27              0.0
# ...           ...                  ...                   ...              ...
# 3007287       NaN  2020-03-31 23:21:00   2020-03-31 23:33:00              NaN
# 3007288       NaN  2020-03-31 23:57:00   2020-04-01 00:26:00              NaN
# 3007289       NaN  2020-03-31 23:22:01   2020-03-31 23:43:52              NaN
# 3007290       NaN  2020-03-31 23:18:53   2020-03-31 23:32:21              NaN
# 3007291       NaN  2020-03-31 23:11:00   2020-03-31 23:30:00              NaN
#
# ...

# %%
## april
april_df = pd.read_csv('./data/2020/yellow_2020-03.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
april_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-03-01 00:31:13   2020-03-01 01:01:42              1.0
# 1             2.0  2020-03-01 00:08:22   2020-03-01 00:08:49              1.0
# 2             1.0  2020-03-01 00:52:18   2020-03-01 00:59:16              1.0
# 3             2.0  2020-03-01 00:47:53   2020-03-01 00:50:57              2.0
# 4             1.0  2020-03-01 00:43:19   2020-03-01 00:58:27              0.0
# ...           ...                  ...                   ...              ...
# 3007287       NaN  2020-03-31 23:21:00   2020-03-31 23:33:00              NaN
# 3007288       NaN  2020-03-31 23:57:00   2020-04-01 00:26:00              NaN
# 3007289       NaN  2020-03-31 23:22:01   2020-03-31 23:43:52              NaN
# 3007290       NaN  2020-03-31 23:18:53   2020-03-31 23:32:21              NaN
# 3007291       NaN  2020-03-31 23:11:00   2020-03-31 23:30:00              NaN
#
# ...
